# %%
library(tidyverse)
library(ggplot2)

# %%
twitch_data <- read_csv("twitchdata-update.csv")
colnames(twitch_data) <- make.names(colnames(twitch_data), unique = TRUE)

twitch_data <- twitch_data |>
select(Mature, Partnered, Followers, Average.viewers)
twitch_data
# Out:
# Rows: 1000 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): Channel, Language
# dbl (7): Watch time(Minutes), Stream time(minutes), Peak viewers, Average vi...
# lgl (2): Partnered, Mature
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#      Mature Partnered Followers Average.viewers
# 1    FALSE  TRUE      3246298   27716
# 2    FALSE  TRUE      5310163   25610
# 3     TRUE  TRUE      1767635   10976
# 4    FALSE  TRUE      3944850    7714
# 5    FALSE  TRUE      8938903   29602
# 6    FALSE  TRUE      1563438   42414
# 7    FALSE  TRUE      4074287   24181
# 8    FALSE  TRUE       508816   18985
# 9    FALSE  TRUE      3530767   22381
# 10   FALSE  TRUE      2607076   12377
# 11    TRUE  TRUE      5265659   25664
# 12   FALSE  TRUE      2666382   21739
# 13   FALSE  TRUE      4487489   20960
# ...

# %%
dt = sort(sample(nrow(twitch_data), nrow(twitch_data)*.7))
training_data <- twitch_data[dt,]
testing_data <- twitch_data[-dt,]

# %%
twitch_table <- twitch_data |> 
group_by(Mature, Partnered, Followers, Average.viewers) |>
summarize(mean = mean(Mature))


twitch_table
# Out:
# `summarise()` has grouped output by 'Mature', 'Partnered', 'Followers'. You can
# override using the `.groups` argument.
#      Mature Partnered Followers Average.viewers mean
# 1    FALSE  FALSE        7102    4530           0
# 2    FALSE  FALSE       30986    1149           0
# 3    FALSE  FALSE       34119    1937           0
# 4    FALSE  FALSE       34358    2465           0
# 5    FALSE  FALSE       85097    3620           0
# 6    FALSE  FALSE       94751    1110           0
# 7    FALSE  FALSE       95371    3069           0
# 8    FALSE  FALSE      146035   35333           0
# 9    FALSE  FALSE      157981    1444           0
# 10   FALSE  FALSE      164902    2434           0
# 11   FALSE  FALSE      173196     476           0
# 12   FALSE  FALSE      252042    2612           0
# 13   FALSE  FALSE      274237    4159           0
# 14   FALSE  FALSE      308815    5864           0
# 15   FALSE  FALSE     1194476    9301           0
# ...

# %%
options(repr.width = 42, repr.height = 6)

variable_distribution <- training_data |>
    ggplot(aes(x = Followers)) +
    geom_histogram() +
    labs(x = "Followers", title = "Distrubution Plot") 

    
variable_distribution
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
